# %%
import pandas as pd

# Example nested JSON structure for Tarif
tarif = {
    "Netznutzung": {
        "winter": {
            "mo-fri": {
                "0": 9.40, "1": 9.40, "2": 9.40, "3": 9.40, "4": 9.40, "5": 9.40, "6": 13.55, "7": 13.55, "8": 13.55, "9": 13.55, "10": 13.55, "11": 13.55, "12": 13.55, "13": 13.55,
                "14": 13.55, "15": 13.55, "16": 13.55, "17": 13.55, "18": 13.55, "19": 13.55,
                "20": 13.55, "21": 9.40, "22": 9.40, "23": 9.40
            },
            "sa": {
                "0": 9.40, "1": 9.40, "2": 9.40, "3": 9.40, "4": 9.40, "5": 9.40, "6": 9.40,
                "7": 9.40, "8": 9.40, "9": 9.40, "10": 9.40, "11": 9.40, "12": 9.40, "13": 9.40,
                "14": 9.40, "15": 9.40, "16": 9.40, "17": 9.40, "18": 9.40, "19": 9.40,
                "20": 9.40, "21": 9.40, "22": 9.40, "23": 9.40
            },
            "su": {
                "0": 9.40, "1": 9.40, "2": 9.40, "3": 9.40, "4": 9.40, "5": 9.40, "6": 9.40,
                "7": 9.40, "8": 9.40, "9": 9.40, "10": 9.40, "11": 9.40, "12": 9.40, "13": 9.40,
                "14": 9.40, "15": 9.40, "16": 9.40, "17": 9.40, "18": 9.40, "19": 9.40,
                "20": 9.40, "21": 9.40, "22": 9.40, "23": 9.40
            }
        },
        "sommer": {
            "mo-fri": {
                "0": 9.40, "1": 9.40, "2": 9.40, "3": 9.40, "4": 9.40, "5": 9.40, "6": 13.55, "7": 13.55, "8": 13.55, "9": 13.55, "10": 13.55, "11": 13.55, "12": 13.55, "13": 13.55,
                "14": 13.55, "15": 13.55, "16": 13.55, "17": 13.55, "18": 13.55, "19": 13.55,
                "20": 13.55, "21": 9.40, "22": 9.40, "23": 9.40
            },
            "sa": {
                "0": 9.40, "1": 9.40, "2": 9.40, "3": 9.40, "4": 9.40, "5": 9.40, "6": 9.40,
                "7": 9.40, "8": 9.40, "9": 9.40, "10": 9.40, "11": 9.40, "12": 9.40, "13": 9.40,
                "14": 9.40, "15": 9.40, "16": 9.40, "17": 9.40, "18": 9.40, "19": 9.40,
                "20": 9.40, "21": 9.40, "22": 9.40, "23": 9.40
            },
            "su": {
                "0": 9.40, "1": 9.40, "2": 9.40, "3": 9.40, "4": 9.40, "5": 9.40, "6": 9.40,
                "7": 9.40, "8": 9.40, "9": 9.40, "10": 9.40, "11": 9.40, "12": 9.40, "13": 9.40,
                "14": 9.40, "15": 9.40, "16": 9.40, "17": 9.40, "18": 9.40, "19": 9.40,
                "20": 9.40, "21": 9.40, "22": 9.40, "23": 9.40
            }
        }
    },
    "Energielieferung": {
        "winter": {
            "mo-fri": {
                "0": 10.10, "1": 10.10, "2": 10.10, "3": 10.10, "4": 10.10, "5": 10.10, "6": 13.25, "7": 13.25, "8": 13.25, "9": 13.25, "10": 13.25, "11": 13.25, "12": 13.25, "13": 13.25,
                "14": 13.25, "15": 13.25, "16": 13.25, "17": 13.25, "18": 13.25, "19": 13.25,
                "20": 13.25, "21": 10.10, "22": 10.10, "23": 10.10
            },
            "sa": {
                "0": 10.10, "1": 10.10, "2": 10.10, "3": 10.10, "4": 10.10, "5": 10.10, "6": 10.10,
                "7": 10.10, "8": 10.10, "9": 10.10, "10": 10.10, "11":10.10, "12": 10.10, "13": 10.10,
                "14": 10.10, "15": 10.10, "16": 10.10, "17": 10.10, "18": 10.10, "19": 10.10,
                "20": 10.10, "21": 10.10, "22": 10.10, "23": 10.10
            },
            "su": {
                "0": 10.10, "1": 10.10, "2": 10.10, "3": 10.10, "4": 10.10, "5": 10.10, "6": 10.10,
                "7": 10.10, "8": 10.10, "9": 10.10, "10": 10.10, "11":10.10, "12": 10.10, "13": 10.10,
                "14": 10.10, "15": 10.10, "16": 10.10, "17": 10.10, "18": 10.10, "19": 10.10,
                "20": 10.10, "21": 10.10, "22": 10.10, "23": 10.10
            }
        },
        "sommer": {
            "mo-fri": {
                "0": 10.10, "1": 10.10, "2": 10.10, "3": 10.10, "4": 10.10, "5": 10.10, "6": 13.25, "7": 13.25, "8": 13.25, "9": 13.25, "10": 13.25, "11": 13.25, "12": 13.25, "13": 13.25,
                "14": 13.25, "15": 13.25, "16": 13.25, "17": 13.25, "18": 13.25, "19": 13.25,
                "20": 13.25, "21": 10.10, "22": 10.10, "23": 10.10
            },
            "sa": {
                "0": 10.10, "1": 10.10, "2": 10.10, "3": 10.10, "4": 10.10, "5": 10.10, "6": 10.10,
                "7": 10.10, "8": 10.10, "9": 10.10, "10": 10.10, "11":10.10, "12": 10.10, "13": 10.10,
                "14": 10.10, "15": 10.10, "16": 10.10, "17": 10.10, "18": 10.10, "19": 10.10,
                "20": 10.10, "21": 10.10, "22": 10.10, "23": 10.10
            },
            "su": {
                "0": 10.10, "1": 10.10, "2": 10.10, "3": 10.10, "4": 10.10, "5": 10.10, "6": 10.10,
                "7": 10.10, "8": 10.10, "9": 10.10, "10": 10.10, "11":10.10, "12": 10.10, "13": 10.10,
                "14": 10.10, "15": 10.10, "16": 10.10, "17": 10.10, "18": 10.10, "19": 10.10,
                "20": 10.10, "21": 10.10, "22": 10.10, "23": 10.10
            }
        }
    }
}

# Step 2: Extract the data
data = []
for category, seasons in tarif.items():
    for season, days in seasons.items():
        for day, hours in days.items():
            for hour, value in hours.items():
                data.append({
                    "Category": category,
                    "Season": season,
                    "Day": day,
                    "Hour": hour,
                    "Value": value
                })
df = pd.DataFrame(data)
df
# Out:
#              Category  Season     Day Hour  Value
# 0         Netznutzung  winter  mo-fri    0    9.4
# 1         Netznutzung  winter  mo-fri    1    9.4
# 2         Netznutzung  winter  mo-fri    2    9.4
# 3         Netznutzung  winter  mo-fri    3    9.4
# 4         Netznutzung  winter  mo-fri    4    9.4
# ..                ...     ...     ...  ...    ...
# 283  Energielieferung  sommer      su   19   10.1
# 284  Energielieferung  sommer      su   20   10.1
# 285  Energielieferung  sommer      su   21   10.1
# 286  Energielieferung  sommer      su   22   10.1
# 287  Energielieferung  sommer      su   23   10.1
#
# [288 rows x 5 columns]

# %%
# Example nested JSON 
durchschnittpreis = {
    "Netznutzung": {
        "grundpreis": 120,
        "leistungspreis": 0,
        "systemdienstleistung": 0.75, 
        "additional_rabatt": 0
    },
    "Energielieferung": {
        "grundpreis": 59,
        "leistungspreis": 0,
        "additional_rabatt": 0
    },
    "Abgaben": [0.34],
    "Netzuschlag": 2.30
}   


flattened_data = []
for key, value in durchschnittpreis.items():
    if isinstance(value, dict):
        for sub_key, sub_value in value.items():
            flattened_data.append({"Category": key, "Type": sub_key, "Value": sub_value})
    elif isinstance(value, list):
        for i, item in enumerate(value):
            flattened_data.append({"Category": key, "Type": f"value_{i+1}", "Value": item})
    else:
        flattened_data.append({"Category": key, "Type": "value", "Value": value})

durch_df = pd.DataFrame(flattened_data)

# Display DataFrame
print(durch_df)
# Out:
#            Category                  Type   Value
# 0       Netznutzung            grundpreis  120.00
# 1       Netznutzung        leistungspreis    0.00
# 2       Netznutzung  systemdienstleistung    0.75
# 3       Netznutzung     additional_rabatt    0.00
# 4  Energielieferung            grundpreis   59.00
# 5  Energielieferung        leistungspreis    0.00
# 6  Energielieferung     additional_rabatt    0.00
# 7           Abgaben               value_1    0.34
# 8  Gemeinde_abgaben               value_1    0.00
# 9       Netzuschlag                 value    2.30

# %%
def durchschnitt_calculation(durchscnitt_df, tariff_df):
    #calculation for Netznutzung
    seasonal_netz_df = get_seasonal_averages(tariff_df, "Netz")
    avg_netz = get_yearly_average_tarif(seasonal_netz_df)
    durch_netz = durchscnitt_df[durchscnitt_df["Category"] == "Netznutzung"].copy().drop(["Category"], axis=1)
    durch_netz.set_index("Type", inplace=True)
    total_netz = ((durch_netz.loc["grundpreis"].Value+durch_netz.loc["leistungspreis"].Value)*100/TOT_VERBRAUCH_H4) + durch_netz.loc["systemdienstleistung"].Value + avg_netz-durch_netz.loc["additional_rabatt"].Value
    
    #calculation for Energielieferung
    seasonal_ener_df = get_seasonal_averages(tariff_df, "Energie")
    avg_ener = get_yearly_average_tarif(seasonal_ener_df)
    durch_ener = durchscnitt_df[durchscnitt_df["Category"] == "Energielieferung"].copy().drop(["Category"], axis=1)
    durch_ener.set_index("Type", inplace=True)
    total_ener = ((durch_ener.loc["grundpreis"].Value+durch_ener.loc["leistungspreis"].Value)*100/TOT_VERBRAUCH_H4) + avg_ener - durch_ener.loc["additional_rabatt"].Value
    
    #calculation Gemeinde Abgaben
    abgaben_max = durchscnitt_df[durchscnitt_df["Category"]=="Abgaben"].Value.max()
    abgaben_min = durchscnitt_df[durchscnitt_df["Category"]=="Abgaben"].Value.min()

    
    #Netzzuschlag
    netzzuschlag = durchscnitt_df[durchscnitt_df["Category"]=="Netzuschlag"].Value
    
    total_duschschnitt_min = total_netz + total_ener + abgaben_min + netzzuschlag
    total_duschschnitt_max = total_netz + total_ener + abgaben_max + netzzuschlag
    return total_duschschnitt_min, total_duschschnitt_max

# %%
durchschnitt_calculation(durch_df, example)
# Out:
# (9    30.454206
#  Name: Value, dtype: float64,
#  9    30.674206
#  Name: Value, dtype: float64)

# %%
h4_verbrauch_df = pd.read_csv("data/hourly_verbrauch_h4.csv")

# %%
df['Hour'] = df['Hour'].astype(int) 
example = pd.merge(df, h4_verbrauch_df, on=["Season", "Hour"], how="left")

# %%
example_n = example.query("Category=='Netznutzung'")

# %%
example_n
# Out:
#         Category  Season     Day  Hour  Value  Verbrauch
# 0    Netznutzung  winter  mo-fri     0    9.4        500
# 1    Netznutzung  winter  mo-fri     1    9.4        500
# 2    Netznutzung  winter  mo-fri     2    9.4        500
# 3    Netznutzung  winter  mo-fri     3    9.4        500
# 4    Netznutzung  winter  mo-fri     4    9.4        500
# ..           ...     ...     ...   ...    ...        ...
# 139  Netznutzung  sommer      su    19    9.4        500
# 140  Netznutzung  sommer      su    20    9.4        500
# 141  Netznutzung  sommer      su    21    9.4        500
# 142  Netznutzung  sommer      su    22    9.4        440
# 143  Netznutzung  sommer      su    23    9.4        440
#
# [144 rows x 6 columns]

# %%
period1 = example_n[(example_n['Hour']>=6) & (example_n['Hour']<12)]
period1
# Out:
#         Category  Season     Day  Hour  Value  Verbrauch
# 6    Netznutzung  winter  mo-fri     6  13.55        690
# 7    Netznutzung  winter  mo-fri     7  13.55        690
# 8    Netznutzung  winter  mo-fri     8  13.55        690
# 9    Netznutzung  winter  mo-fri     9  13.55        690
# 10   Netznutzung  winter  mo-fri    10  13.55        690
# 11   Netznutzung  winter  mo-fri    11  13.55        690
# 30   Netznutzung  winter      sa     6   9.40        690
# 31   Netznutzung  winter      sa     7   9.40        690
# 32   Netznutzung  winter      sa     8   9.40        690
# 33   Netznutzung  winter      sa     9   9.40        690
# 34   Netznutzung  winter      sa    10   9.40        690
# 35   Netznutzung  winter      sa    11   9.40        690
# 54   Netznutzung  winter      su     6   9.40        690
# 55   Netznutzung  winter      su     7   9.40        690
# 56   Netznutzung  winter      su     8   9.40        690
# 57   Netznutzung  winter      su     9   9.40        690
# 58   Netznutzung  winter      su    10   9.40        690
# 59   Netznutzung  winter      su    11   9.40        690
# 78   Netznutzung  sommer  mo-fri     6  13.55        600
# 79   Netznutzung  sommer  mo-fri     7  13.55        600
# 80   Netznutzung  sommer  mo-fri     8  13.55        600
# 81   Netznutzung  sommer  mo-fri     9  13.55        600
# 82   Netznutzung  sommer  mo-fri    10  13.55        600
# 83   Netznutzung  sommer  mo-fri    11  13.55        600
# 102  Netznutzung  sommer      sa     6   9.40        600
# 103  Netznutzung  sommer      sa     7   9.40        600
# 104  Netznutzung  sommer      sa     8   9.40        600
# 105  Netznutzung  sommer      sa     9   9.40        600
# 106  Netznutzung  sommer      sa    10   9.40        600
# 107  Netznutzung  sommer      sa    11   9.40        600
# 126  Netznutzung  sommer      su     6   9.40        600
# 127  Netznutzung  sommer      su     7   9.40        600
# 128  Netznutzung  sommer      su     8   9.40        600
# 129  Netznutzung  sommer      su     9   9.40        600
# 130  Netznutzung  sommer      su    10   9.40        600
# 131  Netznutzung  sommer      su    11   9.40        600

# %%
period1.groupby(['Category', 'Season', 'Day'], as_index = False).mean()
# Out:
#       Category  Season     Day  Hour  Value  Verbrauch
# 0  Netznutzung  sommer  mo-fri   8.5  13.55      600.0
# 1  Netznutzung  sommer      sa   8.5   9.40      600.0
# 2  Netznutzung  sommer      su   8.5   9.40      600.0
# 3  Netznutzung  winter  mo-fri   8.5  13.55      690.0
# 4  Netznutzung  winter      sa   8.5   9.40      690.0
# 5  Netznutzung  winter      su   8.5   9.40      690.0

# %%
def average_on_day_period(df):
    weekly_mean_df = df.groupby(['Category', 'Season', 'Day'], as_index = False).mean()
    for index, row in weekly_mean_df.iterrows():
        if row['Day'] == 'Montag-Freitag':
            weekly_mean_df.loc[index, 'Value'] = row['Value']*5*row['Verbrauch']/(7*100)
        else:
            weekly_mean_df.loc[index, 'Value'] = row['Value']*row['Verbrauch']/(7*100)
    weekly_mean_df.drop(['Category', 'Day', 'Verbrauch', 'Hour'], axis = 1, inplace = True)
    weekly_mean_df.reset_index(drop=True, inplace=True)
    return weekly_mean_df.groupby(['Season'], as_index = False).sum()

# %%
average_on_day_period(period1)
# Out:
#    Season      Value
# 0  sommer  74.185714
# 1  winter  85.313571

# %%
#this function splits the big df in periods, applies iteratively the weekly means for each period and returns a big dataframe with all averages for each season for each period

def get_seasonal_averages(example, category):
    if category not in ['Netz', 'Energie']:
        raise ValueError("Invalid option. Expected 'Netz' or 'Energie'.")
    if category == 'Netz':
        df = example.query("Category=='Netznutzung'")
    else:
        df = example.query("Category=='Energielieferung'")

    # The dataframe is splitted in the periods defined by Elcom
    period1_df = df[(df['Hour']>=6) & (df['Hour']<12)].copy()
    period2_df = df[(df['Hour']>=12) & (df['Hour']<18)].copy()
    period3_df = df[(df['Hour']>=18) & (df['Hour']<22)].copy()
    period4_df = df[(df['Hour']>=22) | (df['Hour']<6)].copy()
    periods = [period1_df, period2_df, period3_df, period4_df]
    averages =[]
    for period_df in periods:
        averages.append(average_on_day_period(period_df))
        
    concatenated_df = pd.concat(averages, axis=0, ignore_index=True)
    return concatenated_df

# %%
get_seasonal_averages(example, 'Energie')
# Out:
#    Season      Value
# 0  sommer  74.185714
# 1  winter  85.313571
# 2  sommer  66.767143
# 3  winter  77.895000
# 4  sommer  58.116071
# 5  winter  69.739286
# 6  sommer  41.360000
# 7  winter  47.000000

# %%
TOT_VERBRAUCH_H4 = 4500
def get_yearly_average_tarif(seasonal_avg_df):
    total_price = seasonal_avg_df['Value'].sum()
    return total_price/TOT_VERBRAUCH_H4*100

# %%
a = get_seasonal_averages(example, 'Energie')
a
# Out:
#    Season    Value
# 0  sommer  74.1000
# 1  winter  85.2150
# 2  sommer  66.6900
# 3  winter  77.8050
# 4  sommer  58.9375
# 5  winter  70.7250
# 6  sommer  44.4400
# 7  winter  50.5000

# %%
get_yearly_average_tarif(a)
# Out:
# np.float64(11.7425)

# %%
b = get_yearly_average_tarif(a)
b
# Out:
# np.float64(11.563928571428574)

# %%
def get_df_from_json(json_file):
    return ()

# %%
import json
with open('../schema/sample-complete.json', 'r', encoding='utf-8') as file:
    input_json = json.load(file)
input_json
# Out:
# {'Netzbetreiber': 'Name des Netzbetreiber',
#  'Produkte': [{'Name': 'The product name',
#    'Beschreibung': 'The product description',
#    'Komponenten': [{'Name': 'Name',
#      'Beschreibung': 'Beschreibung',
#      'Einheit': 'CHF/Monat',
#      'Kategorie': 'Netznutzung',
#      'Unterkategorie': 'Leistungspreis',
#      'Menge': 'Menge',
#      'Tariftyp': 'Einfachtarif',
#      'Tarifzeiten': 'Tarifzeiten'}],
#    'Gültigkeit': 'Gültigkeit',
#    'Verbrauchskategorie': 'Verbrauchskategorie',
#    'Verbrauchstyp': 'weitere',
#    'Netzebene': 'Niederspannung',
#    'Standardprodukt': 'Ja'}],
#  'Netznutzung': {'Winter': {'Montag-Freitag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4},
#    'Samstag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4},
#    'Sonntag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4}},
#   'Sommer': {'Montag-Freitag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4},
#    'Samstag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4},
#    'Sonntag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4}}},
#  'Energielieferung': {'Winter': {'Montag-Freitag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4},
#    'Samstag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4},
#    'Sonntag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4}},
#   'Sommer': {'Montag-Freitag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4},
#    'Samstag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4},
#    'Sonntag': {'Von 00:00 bis 01:00 in Rp./kWh': 9.4,
#     'Von 01:00 bis 02:00 in Rp./kWh': 9.4,
#     'Von 02:00 bis 03:00 in Rp./kWh': 9.4,
#     'Von 03:00 bis 04:00 in Rp./kWh': 9.4,
#     'Von 04:00 bis 05:00 in Rp./kWh': 9.4,
#     'Von 05:00 bis 06:00 in Rp./kWh': 9.4,
#     'Von 06:00 bis 07:00 in Rp./kWh': 13.55,
#     'Von 07:00 bis 08:00 in Rp./kWh': 13.55,
#     'Von 08:00 bis 09:00 in Rp./kWh': 13.55,
#     'Von 09:00 bis 10:00 in Rp./kWh': 13.55,
#     'Von 10:00 bis 11:00 in Rp./kWh': 13.55,
#     'Von 11:00 bis 12:00 in Rp./kWh': 13.55,
#     'Von 12:00 bis 13:00 in Rp./kWh': 13.55,
#     'Von 13:00 bis 14:00 in Rp./kWh': 13.55,
#     'Von 14:00 bis 15:00 in Rp./kWh': 13.55,
#     'Von 15:00 bis 16:00 in Rp./kWh': 13.55,
#     'Von 16:00 bis 17:00 in Rp./kWh': 13.55,
#     'Von 17:00 bis 18:00 in Rp./kWh': 13.55,
#     'Von 18:00 bis 19:00 in Rp./kWh': 13.55,
#     'Von 19:00 bis 20:00 in Rp./kWh': 13.55,
#     'Von 20:00 bis 21:00 in Rp./kWh': 13.55,
#     'Von 21:00 bis 22:00 in Rp./kWh': 9.4,
#     'Von 22:00 bis 23:00 in Rp./kWh': 9.4,
#     'Von 23:00 bis 00:00 in Rp./kWh': 9.4}}},
#  'Durschschnittspreis': {'Netznutzung': {'Grundpreis in CHF': 120,
#    'Leistungspreis in CHF': 0,
#    'Systemdienstleistung in Rp./kWh': 0.75,
#    'ZusätzlicherRabatt in Rp./kWh': 0},
#   'Energielieferung': {'Grundpreis in CHF': 59,
#    'Leistungspreis in CHF': 0,
#    'ZusätzlicherRabatt in Rp./kWh': 0},
#   'Abgaben in Rp./kWh': [0.34],
#   'Stromreserve/Winterstromreserve in in Rp./kWh': 0.4,
#   'Netzuschlag in Rp./kWh': 2.3}}

# %%
def clean_seasonal_data(df):
    #extract the number of the first hour from string
    def extract_first_hour(s):
        split_string = s.split()
        start_time = split_string[1].split(':')  # Extract the '00' part
        return int(start_time[0])  # Convert the hour part to integer
    df['first_hour'] = df['Hour'].apply(extract_first_hour)
    df.drop(['Hour'], axis=1, inplace=True)
    df.rename(columns = {'first_hour': 'Hour'},inplace=True)
    return df

# %%
def extract_df_seasonal_tariffs(input_json):
    tarif = {'Netznutzung': input_json['Netznutzung'], 'Energielieferung': input_json['Energielieferung']}
    data = []
    for category, seasons in tarif.items():
        for season, days in seasons.items():
            for day, hours in days.items():
                for hour, value in hours.items():
                    data.append({
                        "Category": category,
                        "Season": season,
                        "Day": day,
                        "Hour": hour,
                        "Value": value
                    })
        df = pd.DataFrame(data)
        cleaned_df = clean_seasonal_data(df)            
    return cleaned_df

extract_df_seasonal_tariffs(input_json)
# Out:
#              Category  Season             Day  Value  Hour
# 0         Netznutzung  Winter  Montag-Freitag   9.40     0
# 1         Netznutzung  Winter  Montag-Freitag   9.40     1
# 2         Netznutzung  Winter  Montag-Freitag   9.40     2
# 3         Netznutzung  Winter  Montag-Freitag   9.40     3
# 4         Netznutzung  Winter  Montag-Freitag   9.40     4
# ..                ...     ...             ...    ...   ...
# 283  Energielieferung  Sommer         Sonntag  13.55    19
# 284  Energielieferung  Sommer         Sonntag  13.55    20
# 285  Energielieferung  Sommer         Sonntag   9.40    21
# 286  Energielieferung  Sommer         Sonntag   9.40    22
# 287  Energielieferung  Sommer         Sonntag   9.40    23
#
# [288 rows x 5 columns]

# %%
def extract_df_durchschnitt(input_json):
    durchschnitt = input_json['Durschschnittspreis']
    flattened_data = []
    for key, value in durchschnitt.items():
        if isinstance(value, dict):
            for sub_key, sub_value in value.items():
                flattened_data.append({"Category": key, "Type": sub_key, "Value": sub_value})
        elif isinstance(value, list):
            for i, item in enumerate(value):
                flattened_data.append({"Category": key, "Type": f"value_{i+1}", "Value": item})
        else:
            flattened_data.append({"Category": key, "Type": "value", "Value": value})           
    return pd.DataFrame(flattened_data)

# %%
df_durch = extract_df_durchschnitt(input_json)

# %%
df_durch
# Out:
#                  Category                             Type   Value
# 0             Netznutzung                Grundpreis in CHF  120.00
# 1             Netznutzung            Leistungspreis in CHF    0.00
# 2             Netznutzung  Systemdienstleistung in Rp./kWh    0.75
# 3             Netznutzung    ZusätzlicherRabatt in Rp./kWh    0.00
# 4        Energielieferung                Grundpreis in CHF   59.00
# 5        Energielieferung            Leistungspreis in CHF    0.00
# 6        Energielieferung    ZusätzlicherRabatt in Rp./kWh    0.00
# 7      Abgaben in Rp./kWh                          value_1    0.34
# 8  Netzuschlag in Rp./kWh                            value    2.30

# %%
import pandas as pd

# Definition from Elcom H4 period consumption:
# "Wohnung mit einem Gesamtverbrauch pro Jahr von 4,500 kWh, aufgeteilt wie folgt"
h4_verbrauch_df = pd.read_csv("data/hourly_verbrauch_h4.csv")
TOT_VERBRAUCH_H4 = 4500


# Read the input .json and extracts the seasonal, weekly, hourly prices and returns them organized in a dataframe
def extract_df_seasonal_tariffs(input_json):
    tarif = {'Netznutzung': input_json['Netznutzung'], 'Energielieferung': input_json['Energielieferung']}
    data = []
    for category, seasons in tarif.items():
        for season, days in seasons.items():
            for day, hours in days.items():
                for hour, value in hours.items():
                    data.append({
                        "Category": category,
                        "Season": season,
                        "Day": day,
                        "Hour": hour,
                        "Value": value
                    })
        df = pd.DataFrame(data)
        cleaned_df = clean_seasonal_data(df)
    return cleaned_df

# Read the input .json and extracts the prices of the product and returns them organized in a dataframe
def extract_df_durchschnitt(input_json):
    durchschnitt = input_json['Durschschnittspreis']
    flattened_data = []
    for key, value in durchschnitt.items():
        if isinstance(value, dict):
            for sub_key, sub_value in value.items():
                flattened_data.append({"Category": key, "Type": sub_key, "Value": sub_value})
        elif isinstance(value, list):
            for i, item in enumerate(value):
                flattened_data.append({"Category": key, "Type": f"value_{i+1}", "Value": item})
        else:
            flattened_data.append({"Category": key, "Type": "value", "Value": value})
    return pd.DataFrame(flattened_data)

# Change the timings of the dataframe in a series of integers (0 to 23) representing the hours of day
def clean_seasonal_data(df):
    #extract the number of the first hour from string
    def extract_first_hour(s):
        split_string = s.split()
        start_time = split_string[1].split(':')  # Extract the '00' part
        return int(start_time[0])  # Convert the hour part to integer
    df['first_hour'] = df['Hour'].apply(extract_first_hour)
    df.drop(['Hour'], axis=1, inplace=True)
    df.rename(columns = {'first_hour': 'Hour'},inplace=True)
    return df


# This function gets as input the hourly prices from the provider (divided in season, day, hour) and the daily period
# consumptions from Elcom, and it returns the merged dataframe.
def average_price(df_arbeitpreises, h4_verbrauch_df):
    df_arbeitpreises["Hour"] = df_arbeitpreises["Hour"].astype(int)
    elcom_hourly_df = pd.merge(
        df_arbeitpreises, h4_verbrauch_df, on=["Season", "Hour"], how="left"
    )
    return elcom_hourly_df


# This functions take as input the sub-dataframe of Arbeitspreisen referring to the one of the standard daily periods
# defined by Elcom (e.g. 6-12am, 12-18pm etc.) and returns a dataframe containing the average yearly expense (in CHF)
# for that period of time, divided by season (winter and summer).
def average_on_day_period(df):
    weekly_mean_df = df.groupby(["Category", "Season", "Day"], as_index=False).mean()
    for index, row in weekly_mean_df.iterrows():
        if row["Day"] == "Montag-Freitag":
            weekly_mean_df.loc[index, "Value"] = (
                row["Value"] * 5 * row["Verbrauch"] / (7 * 100)
            )
        else:
            weekly_mean_df.loc[index, "Value"] = (
                row["Value"] * row["Verbrauch"] / (7 * 100)
            )
    weekly_mean_df.drop(["Category", "Day", "Verbrauch", "Hour"], axis=1, inplace=True)
    weekly_mean_df.reset_index(inplace=True)
    return weekly_mean_df.groupby(["Season"], as_index=False).sum()


# Split the dataframe containing hourly prices  in periods, applies iteratively the weekly means for each period and
# returns a dataframe with all averages for each season for each period
def get_seasonal_averages(df, category):
    if category not in ["Netz", "Energie"]:
        raise ValueError("Invalid option. Expected 'Netz' or 'Energie'.")
    if category == "Netz":
        df = df.query("Category=='Netznutzung'")
    else:
        df = df.query("Category=='Energielieferung'")

    # The dataframe is splitted in the periods defined by Elcom
    period1_df = df[(df["Hour"] >= 6) & (df["Hour"] < 12)].copy()
    period2_df = df[(df["Hour"] >= 12) & (df["Hour"] < 18)].copy()
    period3_df = df[(df["Hour"] >= 18) & (df["Hour"] < 22)].copy()
    period4_df = df[(df["Hour"] >= 22) | (df["Hour"] < 6)].copy()
    periods = [period1_df, period2_df, period3_df, period4_df]
    averages = []
    for period_df in periods:
        averages.append(average_on_day_period(period_df))

    concatenated_df = pd.concat(averages, axis=0, ignore_index=True)
    return concatenated_df


# Calculate the average yearly price (Rp./kWh) for H4 category
def get_yearly_average_tarif(seasonal_avg_df):
    total_price = seasonal_avg_df["Value"].sum()
    return total_price / TOT_VERBRAUCH_H4 * 100

# Calculate the minimum and maximum average tariff of the product
def durchschnitt_calculation(durchscnitt_df, tariff_df):
    #calculation for Netznutzung
    seasonal_netz_df = get_seasonal_averages(tariff_df, "Netz")
    avg_netz = get_yearly_average_tarif(seasonal_netz_df)
    durch_netz = durchscnitt_df[durchscnitt_df["Category"] == "Netznutzung"].copy().drop(["Category"], axis=1)
    durch_netz.set_index("Type", inplace=True)
    total_netz = ((durch_netz.loc["Grundpreis in CHF"].Value+durch_netz.loc["Leistungspreis in CHF"].Value)*100/TOT_VERBRAUCH_H4) + durch_netz.loc["Systemdienstleistung in Rp./kWh"].Value + avg_netz - durch_netz.loc["ZusätzlicherRabatt in Rp./kWh"].Value
    
    #calculation for Energielieferung
    seasonal_ener_df = get_seasonal_averages(tariff_df, "Energie")
    avg_ener = get_yearly_average_tarif(seasonal_ener_df)
    durch_ener = durchscnitt_df[durchscnitt_df["Category"] == "Energielieferung"].copy().drop(["Category"], axis=1)
    durch_ener.set_index("Type", inplace=True)
    total_ener = ((durch_ener.loc["Grundpreis in CHF"].Value+durch_ener.loc["Leistungspreis in CHF"].Value)*100/TOT_VERBRAUCH_H4) + avg_ener - durch_ener.loc["ZusätzlicherRabatt in Rp./kWh"].Value
    
    #calculation Gemeinde Abgaben
    abgaben_max = durchscnitt_df[durchscnitt_df["Category"]=="Abgaben in Rp./kWh"].Value.max()
    abgaben_min = durchscnitt_df[durchscnitt_df["Category"]=="Abgaben in Rp./kWh"].Value.min()

    # Stromreserve / Winterstromreserve in in Rp. / kWh
    stromreserve = durchscnitt_df[
        durchscnitt_df["Category"]
        == "Stromreserve/Winterstromreserve in in Rp./kWh"
    ].Value.iloc[0]
    
    #Netzzuschlag
    netzzuschlag = durchscnitt_df[durchscnitt_df["Category"]=="Netzuschlag in Rp./kWh"].Value.iloc[0]
    
    total_duschschnitt_min = total_netz + total_ener + abgaben_min + netzzuschlag + stromreserve
    total_duschschnitt_max = total_netz + total_ener + abgaben_max + netzzuschlag + stromreserve
    
    print(type(durchscnitt_df[durchscnitt_df["Category"]=="Netzuschlag in Rp./kWh"].Value.iloc[0]))
    print('total_netz', total_netz)
    print('total_ener', total_ener)
    print('abgaben_min', abgaben_min)
    print('netzzuschlag', netzzuschlag)
    print('stromreserve', stromreserve)
    print('---')
    return total_duschschnitt_min, total_duschschnitt_max

# %%
raw_tarif_df = extract_df_seasonal_tariffs(input_json)
merged_tarif_df = average_price(raw_tarif_df, h4_verbrauch_df)
durchschnitt_df = extract_df_durchschnitt(input_json)
a, b = durchschnitt_calculation(durchschnitt_df, merged_tarif_df)
print(a, b)
# Out:
# <class 'numpy.float64'>
# total_netz 15.846166666666667
# total_ener 13.740611111111113
# abgaben_min 0.34
# netzzuschlag 2.3
# stromreserve 0.4
# ---
# 32.626777777777775 32.626777777777775

# %%
durchschnitt_df
# Out:
#                                         Category  \
# 0                                    Netznutzung
# 1                                    Netznutzung
# 2                                    Netznutzung
# 3                                    Netznutzung
# 4                               Energielieferung
# 5                               Energielieferung
# 6                               Energielieferung
# 7                             Abgaben in Rp./kWh
# 8  Stromreserve/Winterstromreserve in in Rp./kWh
# 9                         Netzuschlag in Rp./kWh
#
#                               Type   Value
# 0                Grundpreis in CHF  120.00
# 1            Leistungspreis in CHF    0.00
# 2  Systemdienstleistung in Rp./kWh    0.75
# 3    ZusätzlicherRabatt in Rp./kWh    0.00
# 4                Grundpreis in CHF   59.00
# 5            Leistungspreis in CHF    0.00
# 6    ZusätzlicherRabatt in Rp./kWh    0.00
# 7                          value_1    0.34
# 8                            value    0.40
# 9                            value    2.30

# %%
stromreserve = durchschnitt_df[
        durchschnitt_df["Category"]
        == "Stromreserve/Winterstromreserve in in Rp./kWh"
    ].Value.iloc[0]
stromreserve
# Out:
# np.float64(0.4)

# %%
def write_output(input_json, output_values):
    if type(output_values) is not list:
        raise ValueError("Invalid option. 'output_values' must be a list.")
    else:
        new_fields = {
            "tiefster Preis [exkl. MWST]": output_values[0],
            "höchster Preis [exkl. MWST]": output_values[1]
        }
        # Create the new structure
        new_json_data = {
            "input": input_json,
            "output": new_fields
        }
        # Write the updated JSON data to a new file
        with open('../output/output.json', 'w', encoding='utf-8') as file:
            json.dump(new_json_data, file, indent=4)

# %%
write_output(input_json, [a,b])
